# %% [markdown]
# # loading csv file

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'loading_csv_file.ipynb',
#  'pandas_dataframe.ipynb',
#  'practice_code.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
superMarketsDf = pandas.read_csv("supermarkets.csv")

# %%
superMarketsDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
superMarketsJsonDf = pandas.read_json("supermarkets.json")

# %%
superMarketsJsonDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
superMarketsXlsxDf = pandas.read_excel("supermarkets.xlsx", sheet_name=0)

# %%
superMarketsXlsxDf
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
superMarketsTxtDf = pandas.read_csv("supermarkets-commas.txt")

# %%
superMarketsTxtDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
superMarketsTxtSemiColonDf = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")

# %%
superMarketsTxtSemiColonDf
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# # Set Table Header Row

# %%
dataDf = pandas.read_csv("data.txt", header=None)

# %%
dataDf
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
dataDf.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]

# %%
dataDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# # Set Index Column

# %%
superMarketsDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
newSupermarketsDf = superMarketsDf.set_index('ID')

# %%
newSupermarketsDf
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
newSupermarketsDf.set_index("Address", inplace=True)

# %%
newSupermarketsDf
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
newSupermarketsDf.set_index("Name", inplace=True, drop=False)

# %%
newSupermarketsDf
# Out:
#                       City             State Country         Name  Employees
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %% [markdown]
# # Filtering Data from a pandas Dataframe

# %%
superMarketsJsonDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
superMarketsJsonDf.loc["1":"4", "Address":"City"]
# Out:
#            Address           City
# 1   735 Dolores St  San Francisco
# 2      332 Hill St  San Francisco
# 3     3995 23rd St  San Francisco
# 4  1056 Sanchez St  San Francisco

# %%
superMarketsJsonDf.loc[4,"State"]
# Out:
# 'California'

# %%
superMarketsJsonDf.loc[:,"Name"]
# Out:
# 0        Madeira
# 1    Bready Shop
# 2    Super River
# 3     Ben's Shop
# 4        Sanchez
# 5     Richvalley
# Name: Name, dtype: object

# %%
list(superMarketsJsonDf.loc[:,"Employees"])
# Out:
# [8, 15, 25, 10, 12, 20]

# %%
superMarketsJsonDf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
superMarketsJsonDf.iloc[2:5, 1:5]
# Out:
#            Address           City             State Country
# 2      332 Hill St  San Francisco  California 94114     USA
# 3     3995 23rd St  San Francisco          CA 94114     USA
# 4  1056 Sanchez St  San Francisco        California     USA

# %%
superMarketsJsonDf.iloc[:, 1:4]
# Out:
#            Address           City             State
# 0     3666 21st St  San Francisco          CA 94114
# 1   735 Dolores St  San Francisco          CA 94119
# 2      332 Hill St  San Francisco  California 94114
# 3     3995 23rd St  San Francisco          CA 94114
# 4  1056 Sanchez St  San Francisco        California
# 5  551 Alvarado St  San Francisco          CA 94114

# %%
superMarketsJsonDf.iloc[3, :]
# Out:
# ID                       4
# Address       3995 23rd St
# City         San Francisco
# State             CA 94114
# Country                USA
# Name            Ben's Shop
# Employees               10
# Name: 3, dtype: object

# %% [markdown]
# # Deleting columns and rows

# %%
supermarketsCopy = superMarketsJsonDf

# %%
supermarketsCopy
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
supermarketsCopy.drop("State", 1)
# Out:
# C:\Users\Rom\AppData\Local\Temp/ipykernel_14048/1442194646.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   supermarketsCopy.drop("State", 1)
#    ID          Address           City Country         Name  Employees
# 0   1     3666 21st St  San Francisco     USA      Madeira          8
# 1   2   735 Dolores St  San Francisco     USA  Bready Shop         15
# 2   3      332 Hill St  San Francisco     USA  Super River         25
# 3   4     3995 23rd St  San Francisco     USA   Ben's Shop         10
# 4   5  1056 Sanchez St  San Francisco     USA      Sanchez         12
# 5   6  551 Alvarado St  San Francisco     USA   Richvalley         20

# %%
supermarketsCopy = supermarketsCopy.drop(4,0)
# Out:
# C:\Users\Rom\AppData\Local\Temp/ipykernel_14048/970419798.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   supermarketsCopy = supermarketsCopy.drop(4,0)

# %%
supermarketsCopy.drop(supermarketsCopy.index[1:3], 0)
# Out:
# C:\Users\Rom\AppData\Local\Temp/ipykernel_14048/2628694633.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   supermarketsCopy.drop(supermarketsCopy.index[1:3], 0)
#    ID          Address           City     State Country        Name  Employees
# 0   1     3666 21st St  San Francisco  CA 94114     USA     Madeira          8
# 3   4     3995 23rd St  San Francisco  CA 94114     USA  Ben's Shop         10
# 5   6  551 Alvarado St  San Francisco  CA 94114     USA  Richvalley         20

# %%
supermarketsCopy.drop(supermarketsCopy.columns[0:2], 1)
# Out:
# C:\Users\Rom\AppData\Local\Temp/ipykernel_14048/1547306981.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   supermarketsCopy.drop(supermarketsCopy.columns[0:2], 1)
#             City             State Country         Name  Employees
# 0  San Francisco          CA 94114     USA      Madeira          8
# 1  San Francisco          CA 94119     USA  Bready Shop         15
# 2  San Francisco  California 94114     USA  Super River         25
# 3  San Francisco          CA 94114     USA   Ben's Shop         10
# 5  San Francisco          CA 94114     USA   Richvalley         20

# %%
supermarketsCopy.index
# Out:
# Int64Index([0, 1, 2, 3, 5], dtype='int64')

# %%
supermarketsCopy.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %% [markdown]
# # Updating and Adding new Columns and Rows

# %%
smdf = superMarketsJsonDf

# %%
smdf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
smdf["Continent"] = smdf.shape[0]*["North America"]

# %%
smdf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
smdf.shape
# Out:
# (6, 8)

# %%
smdf["Continent"] = smdf["Country"]+", "+"North America"

# %%
smdf
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees           Continent
# 0          8  USA, North America
# 1         15  USA, North America
# 2         25  USA, North America
# 3         10  USA, North America
# 4         12  USA, North America
# 5         20  USA, North America

# %%
newSmdf = smdf.T

# %%
newSmdf
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
newSmdf[6] = [7, "My Address", "My City", "My State", "My Country", "My Name", 26, "My Continent"]
# Out:
# C:\Users\Rom\AppData\Local\Temp/ipykernel_14048/3284072790.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   newSmdf = newSmdf.drop("My ID", 1)

# %%
newSmdf
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5  \
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
smdf = newSmdf.T

# %%
smdf
# Out:
#   ID          Address           City             State     Country  \
# 0  1     3666 21st St  San Francisco          CA 94114         USA
# 1  2   735 Dolores St  San Francisco          CA 94119         USA
# 2  3      332 Hill St  San Francisco  California 94114         USA
# 3  4     3995 23rd St  San Francisco          CA 94114         USA
# 4  5  1056 Sanchez St  San Francisco        California         USA
# 5  6  551 Alvarado St  San Francisco          CA 94114         USA
# 6  7       My Address        My City          My State  My Country
#
#           Name Employees           Continent
# 0      Madeira         8  USA, North America
# 1  Bready Shop        15  USA, North America
# 2  Super River        25  USA, North America
# 3   Ben's Shop        10  USA, North America
# 4      Sanchez        12  USA, North America
# 5   Richvalley        20  USA, North America
# 6      My Name        26        My Continent
